# %%
# %matplotlib notebook

# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#filepath
rawData = "Resources/Cleaned Data Date.csv"

# %%
#Read in CSV
rawData_DF = pd.read_csv(rawData, dtype =str)
rawData_DF.head()
# Out:
#     WINTER Winter Start Winter End  CLOSED Closed Date Closed Full Date  \
# 0  1852-53         1852       1853     NaN         NaN             1852
# 1  1853-54         1853       1854  27-Dec      12/27/       12/27/1853
# 2  1854-55         1854       1855     NaN         NaN             1854
# 3  1855-56         1855       1856  18-Dec      12/18/       12/18/1855
# 4  1856-57         1856       1857   6-Dec       12/6/        12/6/1856
#
#    OPENED Opneed Date Opened Full Date DAYS
# 0   5-Apr        4/5/         4/5/1853  NaN
# 1     NaN         NaN             1854  NaN
# 2     NaN         NaN             1855  NaN
# 3  14-Apr       4/14/        4/14/1856  118
# 4   6-May        5/6/         5/6/1857  151

# %%
#Clean_DF = rawData_DF.reindex(columns = ["WINTER", "Winter Start", "CLOSED", "Closed Full Date", "OPENED", "Opened Full Date", "DAYS"])
Clean_DF = rawData_DF
Clean_DF = Clean_DF.dropna()
Clean_DF.head()
# Out:
#     WINTER Winter Start Winter End  CLOSED Closed Date Closed Full Date  \
# 3  1855-56         1855       1856  18-Dec      12/18/       12/18/1855
# 4  1856-57         1856       1857   6-Dec       12/6/        12/6/1856
# 5  1857-58         1857       1858  25-Nov      11/25/       11/25/1857
# 6  1858-59         1858       1859   8-Dec       12/8/        12/8/1858
# 7  1859-60         1859       1860   7-Dec       12/7/        12/7/1859
#
#    OPENED Opneed Date Opened Full Date DAYS
# 3  14-Apr       4/14/        4/14/1856  118
# 4   6-May        5/6/         5/6/1857  151
# 5  26-Mar       3/26/        3/26/1858  121
# 6  14-Mar       3/14/        3/14/1859   96
# 7  26-Mar       3/26/        3/26/1860  110

# %%
#Clean_DF.count()
Clean_DF.dtypes
# Out:
# WINTER              object
# Winter Start        object
# Winter End          object
# CLOSED              object
# Closed Date         object
# Closed Full Date    object
# OPENED              object
# Opneed Date         object
# Opened Full Date    object
# DAYS                object
# dtype: object

# %%
x = Clean_DF["Winter Start"]
y= Clean_DF["DAYS"]
plt.plot(x,y, 'bo')
plt.xticks(np.arange(1850, 2020, step=20))
#plt.yticks()

plt.tick_params(labelright=True)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#"12/27/1853"
a = datetime.datetime(1853, 12, 27)
x = datetime.datetime(2018, 6, 1)

# %%
print(x.strftime("%j"))
# Out:
# 152

# %%
print(a.strftime("%j"))
# Out:
# 361

# %%
#dt = Clean_DF["Closed Full Date"]
dt = "4/14/1856"
month, day, year = (int(x) for x in dt.split('/'))
ans = datetime.date(year, month, day)
z = ans.strftime("%j")
print(z)
# Out:
# 105
