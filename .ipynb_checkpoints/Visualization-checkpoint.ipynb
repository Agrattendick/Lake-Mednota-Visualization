# %%
# %matplotlib notebook

# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#Filepath
filePath = "Resources/Final Date Data.csv"

# %%
#Read in CSV
data_DF = pd.read_csv(filePath)
data_DF.head()
# Out:
#       WINTER  Winter Start  CLOSED Closed Full Date  Julian Closed  OPENED  \
# 157  2013-14          2013  16-Dec       12/16/2013            350  12-Apr
# 158  2014-15          2014   2 Jan         1/2/2014              2   3-Apr
# 159  2015-16          2015  11-Jan        1/11/2015             11  13-Mar
# 160  2016-17          2016   1 Jan         1/1/2016              1   7-Mar
# 161  2017-18          2017  27-Dec       12/27/2017            361  31-Mar
#
#     Opened Full Date  Julian Opened   DAYS
# 157        4/12/2014            102    117
# 158         4/3/2015             93     91
# 159        3/13/2016             73    62
# 160         3/7/2017             66    65
# 161        3/31/2018             90    94

# %%
data_DF.dtypes
# Out:
# WINTER              object
# Winter Start         int64
# CLOSED              object
# Closed Full Date    object
# Julian Closed        int64
# OPENED              object
# Opened Full Date    object
# Julian Opened        int64
# DAYS                object
# dtype: object

# %%
#Plot Data
x = data_DF["Winter Start"]
y = data_DF["Julian Closed"]

plt.plot(x,y, 'bo')
# Out:
# <img src="data:image/png;base64,..." width="640">
